# %%
import pandas as pd
from google.colab import files
df= files.upload()
# Out:
#      <input type="file" id="files-0aaf8a9d-52fb-41c5-bb03-969baa4f88a7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0aaf8a9d-52fb-41c5-bb03-969baa4f88a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("Q7.csv")
df.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
df[["Points","Score","Weigh"]]

# %%
df[["Points","Score","Weigh"]].mean()
# Out:
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
df[["Points","Score","Weigh"]].median()
# Out:
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
print("Mode of given data set is % s" % (df["Points"].mode()))
# Out:
# Mode of given data set is 0    3.07
# 1    3.92
# Name: Points, dtype: float64

# %%
print("Mode of given data set is % s" % (df["Score"].mode()))
# Out:
# Mode of given data set is 0    3.44
# Name: Score, dtype: float64

# %%
print("Mode of given data set is % s" % (df["Weigh"].mode()))
# Out:
# Mode of given data set is 0    17.02
# 1    18.90
# Name: Weigh, dtype: float64

# %%
df[["Points","Score","Weigh"]].var()
# Out:
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %%
df[["Points","Score","Weigh"]].std()
# Out:
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %%
i=df["Points"]
range1=max(i)-min(i)
print("The Range of Points is:",range1)
# Out:
# The Range of Points is: 2.17

# %%
i=df["Score"]
range1=max(i)-min(i)
print("The Range of Points is:",range1)
# Out:
# The Range of Points is: 3.9110000000000005

# %%
i=df["Weigh"]
range1=max(i)-min(i)
print("The Range of Points is:",range1)
# Out:
# The Range of Points is: 8.399999999999999

# %%
df.boxplot(column=['Points','Score','Weigh'], vert=False)

# %%
import pandas as pd
from google.colab import files
df=files.upload()
# Out:
#      <input type="file" id="files-2bbf211e-5314-44d4-8a14-7b7643e33726" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2bbf211e-5314-44d4-8a14-7b7643e33726">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("Q9_a.csv")

# %%
df.head()
# Out:
#    Index  speed  dist
# 0      1      4     2
# 1      2      4    10
# 2      3      7     4
# 3      4      7    22
# 4      5      8    16

# %%
df.shape
# Out:
# (50, 3)

# %%
df.hist(column=['speed','dist'], vert=False)

# %%
import pandas as pd
from google.colab import files
df= files.upload()
# Out:
#      <input type="file" id="files-0de17caf-99dd-4e42-a405-e7eb7f0e6f67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0de17caf-99dd-4e42-a405-e7eb7f0e6f67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("Q9_a.csv")
df.head()
# Out:
#    Index  speed  dist
# 0      1      4     2
# 1      2      4    10
# 2      3      7     4
# 3      4      7    22
# 4      5      8    16

# %%
import pandas as pd
dataframe=pd.DataFrame(data=df);
skewValue=dataframe.skew(axis=1)
print("DataFrame:")
print("Skew")
print(skewValue)
# Out:
# DataFrame:
# Skew
# 0     0.935220
# 1     1.293343
# 2     1.293343
# 3     1.545393
# 4     1.205659
# 5    -1.293343
# 6     1.205659
# 7     1.652317
# 8     1.722329
# 9     1.597097
# 10    1.732051
# 11    1.732051
# 12    1.630059
# 13    1.545393
# 14    1.492769
# 15    1.361301
# 16    1.484685
# 17    1.336096
# 18    1.507808
# 19    0.000000
# 20    1.007538
# 21    1.527874
# 22    1.609654
# 23   -0.330832
# 24   -1.679536
# 25    1.167436
# 26   -1.033882
# 27    0.000000
# 28   -1.457863
# 29   -0.387266
# 30    0.448231
# 31   -0.491613
# 32    0.614794
# 33    1.192952
# 34    1.264991
# 35   -1.732051
# 36   -0.935220
# 37    0.653171
# 38   -0.757035
# 39   -1.152070
# 40   -0.883823
# 41   -0.646969
# 42   -0.136192
# 43    0.000000
# 44   -1.132460
# 45    0.130284
# 46    0.911198
# 47    0.863354
# 48    1.254132
# 49    0.491613
# dtype: float64

# %%
df[["speed","dist"]]
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
dataframe=pd.DataFrame(data=df);
skewValue=dataframe.skew(axis=1)
print("DataFrame:")
print("Skew")
print(skewValue)
# Out:
# DataFrame:
# Skew
# 0     0.935220
# 1     1.293343
# 2     1.293343
# 3     1.545393
# 4     1.205659
# 5    -1.293343
# 6     1.205659
# 7     1.652317
# 8     1.722329
# 9     1.597097
# 10    1.732051
# 11    1.732051
# 12    1.630059
# 13    1.545393
# 14    1.492769
# 15    1.361301
# 16    1.484685
# 17    1.336096
# 18    1.507808
# 19    0.000000
# 20    1.007538
# 21    1.527874
# 22    1.609654
# 23   -0.330832
# 24   -1.679536
# 25    1.167436
# 26   -1.033882
# 27    0.000000
# 28   -1.457863
# 29   -0.387266
# 30    0.448231
# 31   -0.491613
# 32    0.614794
# 33    1.192952
# 34    1.264991
# 35   -1.732051
# 36   -0.935220
# 37    0.653171
# 38   -0.757035
# 39   -1.152070
# 40   -0.883823
# 41   -0.646969
# 42   -0.136192
# 43    0.000000
# 44   -1.132460
# 45    0.130284
# 46    0.911198
# 47    0.863354
# 48    1.254132
# 49    0.491613
# dtype: float64

# %%
import pandas as pd
import numpy as np

# %%
dataMatrix=df
dataFrame=pd.DataFrame(data=dataMatrix);
kurt=dataFrame.kurt(axis=0);
print("Data:")
print(dataFrame)
print("Kurtosis:")
print(kurt)
# Out:
# Data:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# ...

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import statistics

# %%
marks=[34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56]

# %%
statistics.mean(marks)
# Out:
# 41

# %%
statistics.median(marks)
# Out:
# 40.5

# %%
statistics.mode(marks)
# Out:
# 41

# %%
statistics.stdev(marks)
# Out:
# 5.05266382858645

# %%
statistics.variance(marks)
# Out:
# 25.529411764705884

# %%
plt.hist(marks, color='g')
plt.grid()
plt.show()

# %%
plt.boxplot(marks)
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %%
import pandas as pd
from google.colab import files
df= files.upload()
# Out:
#      <input type="file" id="files-7f59f139-d45f-48f1-a32f-368d779c51a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f59f139-d45f-48f1-a32f-368d779c51a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Cars (1).csv")
df.head()

# %%
df['MPG'].mean()
# Out:
# 34.42207572802469

# %%
df['MPG'].median()
# Out:
# 35.15272697

# %%
df['MPG'].mode()
# Out:
# 0    29.629936
# Name: MPG, dtype: float64

# %%
df['MPG'].hist()
# Out:
# <Axes: >

# %%
sns.distplot(df['MPG'])
plt.grid(True)
plt.show()
# Out:
# <ipython-input-32-2be6819da8f5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MPG'])

# %%
df['MPG'].skew()
# Out:
# -0.17794674747025727

# %%
df['MPG'].kurt()
# Out:
# -0.6116786559430913

# %%
import pandas as pd
from google.colab import files
df= files.upload()
# Out:
#      <input type="file" id="files-3895eb5b-2e81-44e3-8b55-9b6b3fa7de7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3895eb5b-2e81-44e3-8b55-9b6b3fa7de7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("wc-at (1).csv")
df.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
df['Waist'].mean()
# Out:
# 91.90183486238531

# %%
df['Waist'].median()
# Out:
# 90.8

# %%
df['Waist'].mode()
# Out:
# 0     94.5
# 1    106.0
# 2    108.5
# Name: Waist, dtype: float64

# %%
df['Waist'].hist()
# Out:
# <Axes: >

# %%
sns.distplot(df['Waist'])
plt.grid(True)
plt.show()
# Out:
# <ipython-input-42-40aa84d807e9>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Waist'])

# %%
df['Waist'].skew()
# Out:
# 0.1340560824786468

# %%
df['Waist'].kurt()
# Out:
# -1.1026666011768886

# %%
df['AT'].mean()
# Out:
# 101.89403669724771

# %%
df['AT'].median()
# Out:
# 96.54

# %%
df['AT'].mode()
# Out:
# 0    121.0
# 1    123.0
# Name: AT, dtype: float64

# %%
df['AT'].hist()
# Out:
# <Axes: >

# %%
sns.distplot(df['AT'])
plt.grid(True)
plt.show()
# Out:
# <ipython-input-50-714e0955e921>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['AT'])

# %%
df['AT'].skew()
# Out:
# 0.584869324127853

# %%
df['AT'].kurt()
# Out:
# -0.28557567504584425

# %%
from scipy import stats
from scipy.stats import norm

# %%
stats.norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %%
stats.norm.ppf(0.97)
# Out:
# 1.8807936081512509

# %%
stats.norm.ppf(0.6)
# Out:
# 0.2533471031357997
